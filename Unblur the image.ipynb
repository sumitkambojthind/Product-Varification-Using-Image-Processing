# %%
import cv2
import os
import matplotlib.pyplot as plt

# %%
path="validImg/Train"
allImg=os.listdir(path)
img=cv2.imread(path+"/"+allImg[0])
plt.imshow(img)

# %%
def add_noise(X,path):
    result = []
    for name in X:
        imgPath=path+"/"+name
        img=cv.imread(imgPath)
        noisy = cv2.GaussianBlur(img, (3, 3), 0)
        noisy = np.clip(noisy, 0, 1)
        result.append(noisy)
    return np.array(result)
allImg=os.listdir(path)
noise_train = add_noise(allImg,path)
# noise_test = add_noise(X_test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 11
#       9     return np.array(result)
#      10 allImg=os.listdir(path)
# ---> 11 noise_train = add_noise(allImg,path)
#
# Cell In[6], line 6, in add_noise(X, path)
#       4 imgPath=path+"/"+name
#       5 img=cv.imread(imgPath)
# ----> 6 noisy = cv2.GaussianBlur(img, (3, 3), 0)
#       7 noisy = np.clip(noisy, 0, 1)
#       8 result.append(noisy)
#
# NameError: name 'cv2' is not defined

# %%
allImg=os.listdir(path)
allImg
# Out:
# ['IMG_20230410_134317.jpg',
#  'IMG_20230410_134343.jpg',
#  'IMG_20230410_135018.jpg',
#  'IMG_20230410_140201_1.jpg',
#  'IMG_20230410_141525.jpg',
#  'IMG_20230410_141612.jpg',
#  'IMG_20230411_153708.jpg',
#  'IMG_20230411_153758.jpg',
#  'IMG_20230411_154000.jpg',
#  'IMG_20230411_154016.jpg',
#  'IMG_20230411_154807.jpg',
#  'IMG_8276.JPG',
#  'IMG_8279.JPG',
#  'IMG_8286.JPG',
#  'IMG_8651.JPG']

# %%
import cv2
cv2
# Out:
# <module 'cv2' from 'F:\\Anaconda\\lib\\site-packages\\cv2\\__init__.py'>

# %%
# !pip install deblurganv2
# Out:
# ERROR: Could not find a version that satisfies the requirement deblurganv2 (from versions: none)
# ERROR: No matching distribution found for deblurganv2
